# %% [markdown]
# # 환경 셋팅

# %%
# !pip install yfinance
# !pip install quantstats
# !pip install finance-datareader
# !pip install PyPortfolioOpt
# !pip install pulp
# !pip install pandas-datareader

# 글꼴 설치
# !apt -qq install fonts-nanum*
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# 'apt'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# matplotlib Setting
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,8)
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.formatter.limits"] = -10000, 10000

# %%
import numpy as np
import pandas as pd
import datetime
import pandas_datareader.data as web
from tqdm import tqdm
import yfinance as yf
import quantstats as qs
import FinanceDataReader as fdr

# %% [markdown]
# # Trading

# %% [markdown]
# ## quantsstats를 이용한 포트폴리오 심층분석

# %%
stock = qs.utils.download_returns('TQQQ')
stock
# Out:
# Date
# 2010-02-11         NaN
# 2010-02-12    0.004094
# 2010-02-16    0.038734
# 2010-02-17    0.016970
# 2010-02-18    0.018958
#                 ...
# 2022-09-12    0.036528
# 2022-09-13   -0.164565
# 2022-09-14    0.022446
# 2022-09-15   -0.050341
# 2022-09-16   -0.019530
# Name: Close, Length: 3172, dtype: float64

# %%
qs.plots.snapshot(stock, title='TQQQ Performance')

# %%
qs.reports.metrics(stock, mode ='basic')
# Out:
#                     Strategy
# ------------------  ----------
# Start Period        2010-02-11
# End Period          2022-09-16
# Risk-Free Rate      0.0%
# Time in Market      100.0%
#
# Cumulative Return   5,601.42%
# CAGR﹪              37.83%
#
# Sharpe              0.84
# Prob. Sharpe Ratio  99.83%
# Sortino             1.17
# Sortino/√2          0.83
# Omega               1.17
#
# Max Drawdown        -75.32%
# Longest DD Days     431
#
# Gain/Pain Ratio     0.17
# Gain/Pain (1M)      1.07
#
# Payoff Ratio        0.92
# Profit Factor       1.17
# Common Sense Ratio  1.09
# CPC Index           0.6
# Tail Ratio          0.93
# Outlier Win Ratio   3.97
# Outlier Loss Ratio  4.1
#
# MTD                 -11.54%
# 3M                  -1.2%
# 6M                  -43.51%
# YTD                 -70.42%
# 1Y                  -66.57%
# 3Y (ann.)           14.72%
# 5Y (ann.)           19.92%
# 10Y (ann.)          33.77%
# All-time (ann.)     37.83%
#
# Avg. Drawdown       -6.89%
# ...

# %% [markdown]
# ## yfinance를 사용하여 종목 데이터 가져오기

# %%
usdkrw = yf.download(['USDKRW=X'],start='1991-01-01', end='2022-09-17')
usdkrw['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2003-12-01    1198.400024
# 2003-12-02    1195.000000
# 2003-12-03    1192.500000
# 2003-12-04    1190.099976
# 2003-12-05    1184.699951
#                  ...
# 2022-09-12    1379.060059
# 2022-09-13    1375.810059
# 2022-09-14    1393.469971
# 2022-09-15    1391.180054
# 2022-09-16    1398.630005
# Name: Close, Length: 4874, dtype: float64

# %%
usdkrw['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
spy = yf.download('SPY','2015-01-01','2020-01-01')
spy["Adj Close"].plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tickers_list = ['AAPL', 'SPY']
data = yf.download(tickers_list,'2015-1-1')['Adj Close']

# Plot all the close prices
((data.pct_change()+1).cumprod()).plot()

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns")

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns')
plt.xlabel('Year')

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
msft = yf.Ticker("MSFT")

# %%
# 마이크로소프트 자산운용사별 보유 수량
msft.institutional_holders
# Out:
#                                Holder     Shares Date Reported   % Out  \
# 0          Vanguard Group, Inc. (The)  628109007    2022-06-29  0.0842
# 1                      Blackrock Inc.  522551885    2022-06-29  0.0701
# 2            State Street Corporation  293557993    2022-06-29  0.0394
# 3                            FMR, LLC  207201641    2022-06-29  0.0278
# 4       Price (T.Rowe) Associates Inc  195859819    2022-06-29  0.0263
# 5       Geode Capital Management, LLC  136945361    2022-06-29  0.0184
# 6                      Morgan Stanley  101931745    2022-06-29  0.0137
# 7             Capital World Investors   98825477    2022-06-29  0.0133
# 8           JP Morgan Chase & Company   91034485    2022-06-29  0.0122
# 9          Northern Trust Corporation   86713343    2022-03-30  0.0116
# 10  Capital Research Global Investors   86423951    2022-03-30  0.0116
# 11    Capital International Investors   85116879    2022-06-29  0.0114
#
#            Value
# 0   153723401823
# ...

# %%
# 배당율
ax = msft.dividends.tail(55).plot(figsize=(15,5))

# %%
# 주식분할
msft.splits
# Out:
# Date
# 1987-09-21    2.0
# 1990-04-16    2.0
# 1991-06-27    1.5
# 1992-06-15    1.5
# 1994-05-23    2.0
# 1996-12-09    2.0
# 1998-02-23    2.0
# 1999-03-29    2.0
# 2003-02-18    2.0
# Name: Stock Splits, dtype: float64

# %%
msft.recommendations.tail(10)
# Out:
#                                Firm    To Grade From Grade Action
# Date
# 2022-07-26 11:02:51      Rosenblatt         Buy              main
# 2022-07-27 10:37:28       Citigroup         Buy              main
# 2022-07-27 10:39:45     BMO Capital  Outperform              main
# 2022-07-27 10:52:52         Wedbush  Outperform              main
# 2022-07-27 11:08:34          Stifel         Buy              main
# 2022-07-27 11:12:18       JP Morgan  Overweight              main
# 2022-07-27 11:14:20   Deutsche Bank         Buy              main
# 2022-07-27 12:50:51     Cowen & Co.  Outperform              main
# 2022-07-29 09:11:53  Wolfe Research  Outperform              main
# 2022-08-12 10:54:35      Guggenheim     Neutral              init

# %%
# 실적 발표일
msft.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-10-24 10:59:00  2022-10-28 12:00:00
# Earnings Average                 2.32                 2.32
# Earnings Low                     2.25                 2.25
# Earnings High                    2.43                 2.43
# Revenue Average           49903200000          49903200000
# Revenue Low               49490000000          49490000000
# Revenue High              51965000000          51965000000

# %% [markdown]
# ### FinanceDataReader를 사용하여 FED 지표 확인

# %%
# ICSA: 주간 실업수당 청구 건수
df = fdr.DataReader(['NASDAQCOM', 'ICSA'], start='2018-01-01', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')
ax = ax.axvspan('2018-01-01', '2022-09-17', color='gray', alpha=0.2)

# %%
# UNRATE: 실업률
df = fdr.DataReader(['NASDAQCOM', 'UNRATE'], start='2018-01-01', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')

# %%
# STLFSI2: 금융스트레스 지수
df = fdr.DataReader(['NASDAQCOM', 'STLFSI2'], start='2018-01-01', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')

# %%
#VIX(변동성 지수)
df = fdr.DataReader(['NASDAQCOM', 'VIXCLS'], start='2018-07-01', data_source='fred')
ax = df.plot(secondary_y='NASDAQCOM')

# %%
# 환율 VS. 나스닥
df_usdkrw = yf.download(['USDKRW=X'], start='2018-01-01')
df_nasdaq = fdr.DataReader(['NASDAQCOM'], start='2018-01-01', data_source='fred')
df_usdkrw.reset_index(inplace=True)
df_nasdaq.reset_index(inplace=True)
df_usdkrw['date'] = pd.to_datetime(df_usdkrw['Date'])
df_nasdaq['date'] = pd.to_datetime(df_nasdaq['DATE'])

df_usdkrw.drop(labels=['Date', 'Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
df_nasdaq.drop(labels=['DATE'], axis=1, inplace=True)

df = pd.merge(df_usdkrw, df_nasdaq, on='date')
df.rename(columns = {'Close' : 'USDKRW'}, inplace=True)
df.set_index('date', inplace=True)

ax = df.plot(secondary_y='NASDAQCOM')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## 무한 매수법 구현

# %%
rate_of_return = 0 # 수익률
realized_pl = 0 # 실현손익
investment = 100000 # 고정 투자금
investment_price = 0 # 매입 금액
investment_total = 0 # 매입 총액

amount = 0 # 평가금액

# %% [markdown]
# 수익률이 10%가 넘은경우 -> 매입금을 실현손익으로

# %%
df['simple_return'] = df['adj_close'].pct_change()
df['log_return'] = np.log(df['adj_close']/df['adj_close'].shift(1))
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'adj_close'
#
# The above exception was the direct cause of the following exception:
#
# ...
