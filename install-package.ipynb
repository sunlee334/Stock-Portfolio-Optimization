# %%
# !pip install pandas
# !pip install tqdm
# !pip install stqdm
# !pip install yfinance
# !pip install quantstats
# !pip install finance-datareader
# !pip install PyPortfolioOpt
# !pip install pulp
# !pip install pandas-datareader
# !pip install streamlit
# Out:
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (1.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from tqdm) (0.4.5)
# Collecting stqdm
#   Downloading stqdm-0.0.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: streamlit>=0.66 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from stqdm) (1.12.2)
# Requirement already satisfied: tqdm>=4.50 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from stqdm) (4.64.1)
# Requirement already satisfied: pympler>=0.9 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (1.0.1)
# Requirement already satisfied: packaging>=14.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (21.3)
# Requirement already satisfied: validators>=0.2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (0.20.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (1.23.3)
# Requirement already satisfied: cachetools>=4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (5.2.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (9.2.0)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (2.8.2)
# Requirement already satisfied: toml in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (4.3.0)
# Requirement already satisfied: rich>=10.11.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (12.5.1)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (8.1.3)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (0.8.0b3)
# Requirement already satisfied: tornado>=5.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (6.2)
# Requirement already satisfied: tzlocal>=1.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (4.2)
# Requirement already satisfied: watchdog in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (2.1.9)
# Requirement already satisfied: pandas>=0.21.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (1.5.0)
# Requirement already satisfied: pyarrow>=4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (9.0.0)
# Requirement already satisfied: semver in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (2.13.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (3.1.27)
# Requirement already satisfied: blinker>=1.0.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (1.5)
# Requirement already satisfied: requests>=2.4 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (2.28.1)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (3.20.2)
# Requirement already satisfied: altair>=3.2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (4.2.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit>=0.66->stqdm) (4.12.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from tqdm>=4.50->stqdm) (0.4.5)
# Requirement already satisfied: toolz in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit>=0.66->stqdm) (0.12.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit>=0.66->stqdm) (3.0.3)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit>=0.66->stqdm) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit>=0.66->stqdm) (4.4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from gitpython!=3.1.19->streamlit>=0.66->stqdm) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from importlib-metadata>=1.4->streamlit>=0.66->stqdm) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from packaging>=14.1->streamlit>=0.66->stqdm) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.21.0->streamlit>=0.66->stqdm) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from python-dateutil->streamlit>=0.66->stqdm) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit>=0.66->stqdm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit>=0.66->stqdm) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit>=0.66->stqdm) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit>=0.66->stqdm) (3.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from rich>=10.11.0->streamlit>=0.66->stqdm) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from rich>=10.11.0->streamlit>=0.66->stqdm) (2.11.2)
# Requirement already satisfied: tzdata in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from tzlocal>=1.1->streamlit>=0.66->stqdm) (2022.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from tzlocal>=1.1->streamlit>=0.66->stqdm) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from validators>=0.2->streamlit>=0.66->stqdm) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.66->stqdm) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from jinja2->altair>=3.2.0->streamlit>=0.66->stqdm) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.66->stqdm) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.66->stqdm) (0.18.0)
# Installing collected packages: stqdm
# Successfully installed stqdm-0.0.4
# Requirement already satisfied: yfinance in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (0.1.74)
# Requirement already satisfied: lxml>=4.5.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: numpy>=1.15 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance) (1.23.3)
# Requirement already satisfied: requests>=2.26 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=0.24.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance) (1.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: quantstats in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (0.0.59)
# Requirement already satisfied: scipy>=1.2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (1.9.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (1.23.3)
# Requirement already satisfied: tabulate>=0.8.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (0.8.10)
# Requirement already satisfied: python-dateutil>=2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (2.8.2)
# Requirement already satisfied: pandas>=0.24.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (1.5.0)
# Requirement already satisfied: yfinance>=0.1.70 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (0.1.74)
# Requirement already satisfied: seaborn>=0.9.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (0.12.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from quantstats) (3.6.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from matplotlib>=3.0.0->quantstats) (4.37.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from matplotlib>=3.0.0->quantstats) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from matplotlib>=3.0.0->quantstats) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from matplotlib>=3.0.0->quantstats) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from matplotlib>=3.0.0->quantstats) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from matplotlib>=3.0.0->quantstats) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from matplotlib>=3.0.0->quantstats) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.24.0->quantstats) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from python-dateutil>=2.0->quantstats) (1.16.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance>=0.1.70->quantstats) (4.9.1)
# Requirement already satisfied: requests>=2.26 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from yfinance>=0.1.70->quantstats) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (2.0.4)
# Requirement already satisfied: finance-datareader in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (0.9.34)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from finance-datareader) (4.64.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from finance-datareader) (1.5.0)
# Requirement already satisfied: requests-file in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from finance-datareader) (2.28.1)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from finance-datareader) (4.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.3.0->finance-datareader) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.11)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from tqdm->finance-datareader) (0.4.5)
# Requirement already satisfied: PyPortfolioOpt in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (1.5.3)
# Requirement already satisfied: pandas>=0.19 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from PyPortfolioOpt) (1.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from PyPortfolioOpt) (1.23.3)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from PyPortfolioOpt) (1.2.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from PyPortfolioOpt) (1.9.1)
# Requirement already satisfied: ecos>=2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.10)
# Requirement already satisfied: osqp>=0.4.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post5)
# Requirement already satisfied: scs>=1.1.6 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2022.1)
# Requirement already satisfied: qdldl in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Requirement already satisfied: pulp in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (2.6.0)
# Requirement already satisfied: pandas-datareader in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (0.10.0)
# Requirement already satisfied: pandas>=0.23 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas-datareader) (1.5.0)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas-datareader) (2.28.1)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.11)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)
# Requirement already satisfied: streamlit in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (1.12.2)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (1.23.3)
# Requirement already satisfied: gitpython!=3.1.19 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: validators>=0.2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (0.8.0b3)
# Requirement already satisfied: watchdog in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (2.1.9)
# Requirement already satisfied: tornado>=5.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (6.2)
# Requirement already satisfied: pandas>=0.21.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (1.5.0)
# Requirement already satisfied: toml in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: cachetools>=4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: requests>=2.4 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: semver in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: packaging>=14.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: tzlocal>=1.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: pyarrow>=4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: pympler>=0.9 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (4.12.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (3.20.2)
# Requirement already satisfied: rich>=10.11.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (12.5.1)
# Requirement already satisfied: blinker>=1.0.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: altair>=3.2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit) (3.0.3)
# Requirement already satisfied: toolz in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit) (4.4.0)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from rich>=10.11.0->streamlit) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from rich>=10.11.0->streamlit) (2.11.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.2)
# Requirement already satisfied: decorator>=3.4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\envs\stock-portfolio-optimization\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
